# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Entendimiento:

# %%
Accion name_2.1.5 Es
===================================================================================================
Accion Generar_Socios_Faltantes Es
  AMBIENTE
    Sec_e : Secuencia de Enteros; 
    Sec_s : Secuencia de Enteros; 
    primero : Entero;              
    segundo : Entero;  
    v : entero;

  PROCESO
    Crear(Sec_s)
    ARR(Sec_e); // Abrir entrada
    ARR(Sec_s); // Abrir salida
    AVZ(Sec_e, v); 

    cont := 0 
     
    Mientras NFDS(Sec_e) Hacer
        cont:= cont + 1 
        Si cont = v Entonces
          AVZ(Sec_e)
        Sino
          ESCRIBIR(Sec_s,cont) 
        Fsi
    FMientras
    CERRAR(Sec_e);
    CERRAR(Sec_s);
    Escribir('Proceso finalizado. Socios faltantes en Sec_s.')

Fin Accion
===================================================================================================
Sec Entrada                  cont(1) =   v(2) 
2 4 7 9 10 22 45     
                             cont(2) >=  v(2) 
Sec Salida
1 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
33356 | 2343242 | 342342 | 42344 |423454

===================================================================================================
Accion eje 2.1.6 Es
Ambiente 
    sec: secuencia de enteros
    v: entero
    i: entero

    v_may18: entero
    v_men18: entero
    m_may18: entero
    m_men18: entero
    total: entero

Proceso
    arr(sec);
    avz(sec,v); // estoy en el primer elemento
    v_may18:= 0
    v_men18:= 0
    m_may18:= 0
    m_men18:= 0

    Mientras nfds(sec) hacer
        Para i:= 1 hasta 23 hacer // trato las provincias
            v_may18:= v_may18 + v
            avz(sec,v)
            v_men18:= v_may18 + v
            avz(sec,v)
            m_may18:= v_may18 + v
            avz(sec,v)
            m_men18:= v_may18 + v
            avz(sec,v)
        fp
        total:= v_may18 + v_men18 + m_may18 + m_men18
        v_may18:= (v_may18 / total);
        v_men18:= (v_may18 / total);
        m_may18:= (v_may18 / total);
        m_men18:= (v_may18 / total);
    fm

    cerrar(sec)

| 200 | 300 | 250 | 400 |


avz(sec,v)

para i:= 1 a 7 hacer
    avz(sec,v)
fp

| p | a | l | a | b | r | a | 1 | 2 | 3
